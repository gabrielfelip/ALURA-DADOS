# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielfelip/ALURA-DADOS/blob/main/alura_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Aula 1 - Analisando dados do documento, renomeando colunas etc.**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape [0], df.shape [1]
print ("Linhas:", linhas)
print ("Colunas", colunas)
# Out:
# Linhas: 133349
# Colunas 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Out:
#       ano senioridade emprego               cargo  salario moeda_salario  \
# 0  2025.0          SE      FT  Solutions Engineer   214000           USD
# 1  2025.0          SE      FT  Solutions Engineer   136000           USD
# 2  2025.0          MI      FT       Data Engineer   158800           USD
# 3  2025.0          MI      FT       Data Engineer   139200           USD
# 4  2025.0          EN      FT       Data Engineer    90000           USD
#
#    salario_usd residencia_empregado  remoto empresa tamanho_empresa
# 0       214000                   US     100      US               M
# 1       136000                   US     100      US               M
# 2       158800                   AU       0      AU               M
# 3       139200                   AU       0      AU               M
# 4        90000                   US       0      US               M

# %%
df["senioridade"].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df['remoto'] = df['remoto'].replace({
    100: 'Remoto',
    50: 'Híbrido',
    0: 'Presencial'
})

display(df.head())
# Out:
#       ano senioridade emprego               cargo  salario moeda_salario  \
# 0  2025.0          SE      FT  Solutions Engineer   214000           USD
# 1  2025.0          SE      FT  Solutions Engineer   136000           USD
# 2  2025.0          MI      FT       Data Engineer   158800           USD
# 3  2025.0          MI      FT       Data Engineer   139200           USD
# 4  2025.0          EN      FT       Data Engineer    90000           USD
#
#    salario_usd residencia_empregado      remoto empresa tamanho_empresa
# 0       214000                   US      Remoto      US               M
# 1       136000                   US      Remoto      US               M
# 2       158800                   AU  Presencial      AU               M
# 3       139200                   AU  Presencial      AU               M
# 4        90000                   US  Presencial      US               M

# %%
df.head()
# Out:
#       ano senioridade emprego               cargo  salario moeda_salario  \
# 0  2025.0          SE      FT  Solutions Engineer   214000           USD
# 1  2025.0          SE      FT  Solutions Engineer   136000           USD
# 2  2025.0          MI      FT       Data Engineer   158800           USD
# 3  2025.0          MI      FT       Data Engineer   139200           USD
# 4  2025.0          EN      FT       Data Engineer    90000           USD
#
#    salario_usd residencia_empregado      remoto empresa tamanho_empresa
# 0       214000                   US      Remoto      US               M
# 1       136000                   US      Remoto      US               M
# 2       158800                   AU  Presencial      AU               M
# 3       139200                   AU  Presencial      AU               M
# 4        90000                   US  Presencial      US               M

# %%
df.describe(include="object")
# Out:
#        senioridade emprego           cargo moeda_salario residencia_empregado  \
# count       133349  133349          133349        133349               133349
# unique           4       4             390            26                  102
# top             SE      FT  Data Scientist           USD                   US
# freq         77241  132563           17314        126140               119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US               M
# freq        105312  119641          129561

# %%
df.head()
# Out:
#       ano senioridade emprego               cargo  salario moeda_salario  \
# 0  2025.0          SE      FT  Solutions Engineer   214000           USD
# 1  2025.0          SE      FT  Solutions Engineer   136000           USD
# 2  2025.0          MI      FT       Data Engineer   158800           USD
# 3  2025.0          MI      FT       Data Engineer   139200           USD
# 4  2025.0          EN      FT       Data Engineer    90000           USD
#
#    salario_usd residencia_empregado      remoto empresa tamanho_empresa
# 0       214000                   US      Remoto      US               M
# 1       136000                   US      Remoto      US               M
# 2       158800                   AU  Presencial      AU               M
# 3       139200                   AU  Presencial      AU               M
# 4        90000                   US  Presencial      US               M

# %%
# Out:
#       ano senioridade emprego               cargo  salario moeda_salario  \
# 0  2025.0      Sênior      FT  Solutions Engineer   214000           USD
# 1  2025.0      Sênior      FT  Solutions Engineer   136000           USD
# 2  2025.0       Pleno      FT       Data Engineer   158800           USD
# 3  2025.0       Pleno      FT       Data Engineer   139200           USD
# 4  2025.0      Júnior      FT       Data Engineer    90000           USD
#
#    salario_usd residencia_empregado      remoto empresa tamanho_empresa
# 0       214000                   US      Remoto      US               M
# 1       136000                   US      Remoto      US               M
# 2       158800                   AU  Presencial      AU               M
# 3       139200                   AU  Presencial      AU               M
# 4        90000                   US  Presencial      US               M

# %%
# Out:
#       ano senioridade         emprego               cargo  salario  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0               M
# 1               M
# 2               M
# 3               M
# 4               M

# %%
df['tamanho_empresa'] = df['tamanho_empresa'].replace({
    'S': 'Pequena',
    'M': 'Média',
    'L': 'Grande'
})

display(df.head())
# Out:
#       ano senioridade         emprego               cargo  salario  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0           Média
# 1           Média
# 2           Média
# 3           Média
# 4           Média

# %% [markdown]
# ## **Aula  - Preparação e limpeza de dados.**

# %%
df.head()
# Out:
#       ano senioridade         emprego               cargo  salario  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0           Média
# 1           Média
# 2           Média
# 3           Média
# 4           Média

# %%
df.isnull()
# Out:
#           ano  senioridade  emprego  cargo  salario  moeda_salario  \
# 0       False        False    False  False    False          False
# 1       False        False    False  False    False          False
# 2       False        False    False  False    False          False
# 3       False        False    False  False    False          False
# 4       False        False    False  False    False          False
# ...       ...          ...      ...    ...      ...            ...
# 133344  False        False    False  False    False          False
# 133345  False        False    False  False    False          False
# 133346  False        False    False  False    False          False
# 133347  False        False    False  False    False          False
# 133348  False        False    False  False    False          False
#
#         salario_usd  residencia_empregado  remoto  empresa  tamanho_empresa
# 0             False                 False   False    False            False
# ...

# %%
df.isnull().sum()
# Out:
# ano                     10
# senioridade              0
# emprego                  0
# cargo                    0
# salario                  0
# moeda_salario            0
# salario_usd              0
# residencia_empregado     0
# remoto                   0
# empresa                  0
# tamanho_empresa          0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade         emprego                      cargo  salario  \
# 5588    NaN      Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN      Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# ...

# %%
import numpy as np
df_salarios = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Diana', 'Eduardo'],
    'salario': [4000, np.nan, 3500, np.nan, 5000]
})

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome  salario  salario_media  salario_mediana
# 0      Ana   4000.0        4000.00           4000.0
# 1    Bruno      NaN        4166.67           4000.0
# 2   Carlos   3500.0        3500.00           3500.0
# 3    Diana      NaN        4166.67           4000.0
# 4  Eduardo   5000.0        5000.00           5000.0

# %%
df_temperaturas = pd.DataFrame({
    'dia': ['Seg', 'Ter', 'Qua', 'Qui', 'Sex'],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas['preenchido_bfill'] = df_temperaturas['temperatura'].bfill()

df_temperaturas
# Out:
#    dia  temperatura  preenchido_bfill
# 0  Seg         30.0              30.0
# 1  Ter          NaN              28.0
# 2  Qua          NaN              28.0
# 3  Qui         28.0              28.0
# 4  Sex         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Diana', 'Eduardo'],
    'cidade': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Salvador']
})

df_cidades['cidade_corrigida'] = df_cidades['cidade'].fillna('Não informado')

df_cidades
# Out:
#       nome     cidade cidade_corrigida
# 0      Ana  São Paulo        São Paulo
# 1    Bruno        NaN    Não informado
# 2   Carlos   Curitiba         Curitiba
# 3    Diana        NaN    Não informado
# 4  Eduardo   Salvador         Salvador

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                     0
# senioridade             0
# emprego                 0
# cargo                   0
# salario                 0
# moeda_salario           0
# salario_usd             0
# residencia_empregado    0
# remoto                  0
# empresa                 0
# tamanho_empresa         0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade         emprego               cargo  salario  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0           Média
# 1           Média
# 2           Média
# 3           Média
# 4           Média

# %%
df_limpo = df_limpo.assign(ano=df_limpo['ano'].astype('Int64'))

# %%
df_limpo.head()
# Out:
#     ano senioridade         emprego               cargo  salario  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0           Média
# 1           Média
# 2           Média
# 3           Média
# 4           Média

# %%
df_limpo.to_csv('dados-imersao.csv', index=False)

# %%
df_limpo.head()
# Out:
#     ano senioridade         emprego               cargo  salario  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_usd residencia_empregado      remoto empresa  \
# 0           USD       214000                   US      Remoto      US
# 1           USD       136000                   US      Remoto      US
# 2           USD       158800                   AU  Presencial      AU
# 3           USD       139200                   AU  Presencial      AU
# 4           USD        90000                   US  Presencial      US
#
#   tamanho_empresa
# 0           Média
# 1           Média
# 2           Média
# 3           Média
# 4           Média

# %%
df['senioridade'].value_counts().plot(kind='bar', title='Distribuição dos níveis de experiência')
# Out:
# <Axes: title={'center': 'Distribuição dos níveis de experiência'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd', estimator='mean')
# Out:
# <Axes: xlabel='senioridade', ylabel='salario_usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd', estimator='mean')
plt.title('Salário médio por nível de senioridade')
plt.ylabel('Salário médio (USD)')
plt.xlabel('Senioridade')
plt.show()

# %%
df.groupby('senioridade')['salario_usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Sênior       172850.003845
# Pleno        143041.323489
# Júnior        99039.040264
# Name: salario_usd, dtype: float64

# %%
ordem = df.groupby('senioridade')['salario_usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['Executivo', 'Sênior', 'Pleno', 'Júnior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd', estimator='mean', order=ordem)
plt.title('Salário médio por nível de senioridade')
plt.ylabel('Salário Médio (USD)')
plt.xlabel('Senioridade')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_limpo['salario_usd'], bins=50, kde=True)
plt.title('Distribuição dos Salários')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_limpo['salario_usd'])
plt.title('Boxplot dos salários')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Júnior', 'Pleno', 'Sênior', 'Executivo']

plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='salario_usd', data=df, order=ordem_senioridade)
plt.title('Distribuição salarial por nível de experiência')
plt.xlabel('Senioridade')
plt.ylabel('Salário (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='salario_usd', data=df, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title('Distribuição salarial por nível de experiência')
plt.xlabel('Senioridade')
plt.ylabel('Salário (USD)')
plt.show()

# %%
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds = df_ds.groupby('residencia_empregado')['salario_usd'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 5))
sns.barplot(x='residencia_empregado', y='salario_usd', data=media_ds.head(5))
plt.title('Top 5 Países que com maiores médias salarias para Cientistas de Dados')
plt.xlabel('País')
plt.ylabel('Salário Médio (USD)')
plt.show()

# %%
import plotly.express as px

# %%
# Calcular média salarial
media_senioridade = df.groupby('senioridade')['salario_usd'].mean().reset_index()

# Criar gráfico
fig = px.bar(media_senioridade, x='senioridade', y='salario_usd',
             title='Salário Médio por Nível de Senioridade',
             labels={'senioridade': 'Senioridade', 'salario_usd': 'Salário Médio (USD)'},
             color='senioridade')

fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['emprego', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='emprego',
    values='quantidade',
    title='Proporção dos Tipos de Trabalho',
    hole=0.5  # opcional: transforma em donut chart
)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_cargos = df_limpo.groupby('cargo')['salario_usd'].mean().round(2).sort_values(ascending=False).head().reset_index()
top_cargos
# Out:
#                            cargo  salario_usd
# 0             Research Team Lead     450000.0
# 1  Analytics Engineering Manager     399880.0
# 2         Data Science Tech Lead     375000.0
# 3             Applied AI ML Lead     292500.0
# 4             Head of Applied AI     273875.0

# %%
# Gráfico interativo
fig = px.bar(
    top_cargos,
    x='cargo',
    y='salario_usd',
    title='Top 5 cargos com maiores médias salariais',
    labels={'usd': 'Salário médio (USD)', 'cargo': 'Cargo'}
)
fig.update_layout(xaxis_title='Cargo', yaxis_title='Salário médio (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 79.0 MB/s eta 0:00:00
# ...

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia_empregado'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['salario_usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='salario_usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)
